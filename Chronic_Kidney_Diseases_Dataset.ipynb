# %%
import pandas as pd

# %%
import numpy as np

# %%
dataset = pd.read_csv("kidney_disease.csv")

# %%
dataset
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
dataset.isna().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
dataset.info
# Out:
# <bound method DataFrame.info of       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
dataset.isnull
# Out:
# <bound method DataFrame.isnull of       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
dataset.isnull()
# Out:
#         id    age     bp     sg     al     su    rbc     pc    pcc     ba  \
# 0    False  False  False  False  False  False   True  False  False  False
# 1    False  False  False  False  False  False   True  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 395  False  False  False  False  False  False  False  False  False  False
# 396  False  False  False  False  False  False  False  False  False  False
# 397  False  False  False  False  False  False  False  False  False  False
# 398  False  False  False  False  False  False  False  False  False  False
# 399  False  False  False  False  False  False  False  False  False  False
#
#      ...    pcv     wc     rc    htn     dm    cad  appet     pe    ane  \
# ...

# %%
dataset.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
dataset["appet"]=dataset["appet"].fillna(dataset["appet"].mode()[0])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dataset["appet"].max()
#
# NameError: name 'dataset' is not defined

# %%
dataset["appet"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["pe"].isna().sum()
# Out:
# np.int64(1)

# %%
dataset["pe"]=dataset["pe"].fillna(dataset["pe"].mode()[0])

# %%
dataset["pe"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["ane"].isna().sum()
# Out:
# np.int64(1)

# %%
dataset["ane"]=dataset["ane"].fillna(dataset["ane"].mode()[0])

# %%
dataset["ane"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["cad"].isna().sum()
# Out:
# np.int64(2)

# %%
dataset["cad"]=dataset["cad"].fillna(dataset["cad"].mode()[0])

# %%
dataset["cad"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["dm"].isna().sum()
# Out:
# np.int64(2)

# %%
dataset["dm"]=dataset["dm"].fillna(dataset["dm"].mode()[0])

# %%
dataset["dm"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["htn"].isna().sum()
# Out:
# np.int64(2)

# %%
dataset["htn"]=dataset["htn"].fillna(dataset["htn"].mode()[0])

# %%
dataset["htn"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["rc"].isna().sum()
# Out:
# np.int64(130)

# %%
print(dataset["rc"].dtype)
print(dataset["rc"].unique())
# Out:
# object
# ['5.2' nan '3.9' '4.6' '4.4' '5' '4.0' '3.7' '3.8' '3.4' '2.6' '2.8' '4.3'
#  '3.2' '3.6' '4' '4.1' '4.9' '2.5' '4.2' '4.5' '3.1' '4.7' '3.5' '6.0'
#  '5.0' '2.1' '5.6' '2.3' '2.9' '2.7' '8.0' '3.3' '3.0' '3' '2.4' '4.8'
#  '\t?' '5.4' '6.1' '6.2' '6.3' '5.1' '5.8' '5.5' '5.3' '6.4' '5.7' '5.9'
#  '6.5']

# %%
# Remove leading/trailing spaces and tabs
dataset["rc"] = dataset["rc"].astype(str).str.strip()

# Replace '?' with NaN
dataset["rc"] = dataset["rc"].replace("?", np.nan)

# Convert to numeric
dataset["rc"] = pd.to_numeric(dataset["rc"], errors="coerce")

# Fill missing values with the median
dataset["rc"] = dataset["rc"].fillna(dataset["rc"].median())

# %%
dataset["rc"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["rc"].dtype
# Out:
# dtype('float64')

# %%
dataset["wc"].isna().sum()
# Out:
# np.int64(105)

# %%
print(dataset["wc"].dtype)
print(dataset["wc"].unique())
# Out:
# object
# ['7800' '6000' '7500' '6700' '7300' nan '6900' '9600' '12100' '4500'
#  '12200' '11000' '3800' '11400' '5300' '9200' '6200' '8300' '8400' '10300'
#  '9800' '9100' '7900' '6400' '8600' '18900' '21600' '4300' '8500' '11300'
#  '7200' '7700' '14600' '6300' '\t6200' '7100' '11800' '9400' '5500' '5800'
#  '13200' '12500' '5600' '7000' '11900' '10400' '10700' '12700' '6800'
#  '6500' '13600' '10200' '9000' '14900' '8200' '15200' '5000' '16300'
#  '12400' '\t8400' '10500' '4200' '4700' '10900' '8100' '9500' '2200'
#  '12800' '11200' '19100' '\t?' '12300' '16700' '2600' '26400' '8800'
#  '7400' '4900' '8000' '12000' '15700' '4100' '5700' '11500' '5400' '10800'
#  '9900' '5200' '5900' '9300' '9700' '5100' '6600']

# %%
import numpy as np
import pandas as pd

# Remove leading/trailing spaces and tab characters
dataset["wc"] = dataset["wc"].astype(str).str.strip()

# Replace '?' with NaN
dataset["wc"] = dataset["wc"].replace("?", np.nan)

# Convert to numeric
dataset["wc"] = pd.to_numeric(dataset["wc"], errors="coerce")

# Fill missing values with the median
dataset["wc"] = dataset["wc"].fillna(dataset["wc"].median())

# %%
dataset["wc"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["pcv"].isna().sum()
# Out:
# np.int64(70)

# %%
print(dataset["pcv"].dtype)
print(dataset["pcv"].unique())
# Out:
# object
# ['44' '38' '31' '32' '35' '39' '36' '33' '29' '28' nan '16' '24' '37' '30'
#  '34' '40' '45' '27' '48' '\t?' '52' '14' '22' '18' '42' '17' '46' '23'
#  '19' '25' '41' '26' '15' '21' '43' '20' '\t43' '47' '9' '49' '50' '53'
#  '51' '54']

# %%
# Remove leading/trailing spaces and tab characters
dataset["wc"] = dataset["wc"].astype(str).str.strip()

# Replace '?' with NaN
dataset["wc"] = dataset["wc"].replace("?", np.nan)

# Convert to numeric
dataset["wc"] = pd.to_numeric(dataset["wc"], errors="coerce")

# Fill missing values with the median
dataset["wc"] = dataset["wc"].fillna(dataset["wc"].median())

# %%
dataset["wc"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["hemo"].isna().sum()
# Out:
# np.int64(52)

# %%
dataset["hemo"].dtype
# Out:
# dtype('float64')

# %%
dataset["hemo"] = dataset["hemo"].fillna(dataset["hemo"].median())

# %%
dataset["hemo"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["pot"].isna().sum()
# Out:
# np.int64(88)

# %%
dataset["pot"] = dataset["pot"].fillna(dataset["pot"].median())

# %%
dataset["pot"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["sod"].isna().sum()
# Out:
# np.int64(87)

# %%
dataset["pot"] = dataset["pot"].fillna(dataset["pot"].median())

# %%
dataset["sc"].isna().sum()
# Out:
# np.int64(17)

# %%
dataset["sc"] = dataset["sc"].fillna(dataset["sc"].median())

# %%
dataset["sc"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["sod"].isna().sum()
# Out:
# np.int64(87)

# %%
dataset["sod"] = dataset["sod"].fillna(dataset["sod"].median())

# %%
dataset["sod"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["bu"].isna().sum()
# Out:
# np.int64(19)

# %%
dataset["bu"] = dataset["bu"].fillna(dataset["bu"].median())

# %%
dataset["bu"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["bgr"].isna().sum()
# Out:
# np.int64(44)

# %%
dataset["bgr"] = dataset["bgr"].fillna(dataset["bgr"].median())

# %%
dataset["bgr"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["bgr"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["ba"] = dataset["ba"].fillna(dataset["ba"].mode()[0])

# %%
dataset["ba"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["pcc"].isna().sum()
# Out:
# np.int64(4)

# %%
dataset["pcc"] = dataset["pcc"].fillna(dataset["pcc"].mode()[0])

# %%
dataset["pcc"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["pc"].isna().sum()
# Out:
# np.int64(65)

# %%
dataset["pc"] = dataset["pc"].fillna(dataset["pc"].mode()[0])

# %%
dataset["pc"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["rbc"].isna().sum()
# Out:
# np.int64(152)

# %%
dataset["rbc"] = dataset["rbc"].fillna(dataset["rbc"].mode()[0])

# %%
dataset["rbc"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["su"].isna().sum()
# Out:
# np.int64(49)

# %%
dataset["su"].unique
# Out:
# <bound method Series.unique of 0      0.0
# 1      0.0
# 2      3.0
# 3      0.0
# 4      0.0
#       ...
# 395    0.0
# 396    0.0
# 397    0.0
# 398    0.0
# 399    0.0
# Name: su, Length: 400, dtype: float64>

# %%
dataset["su"] = dataset["su"].fillna(0)

# %%
dataset["su"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["al"].isna().sum()
# Out:
# np.int64(46)

# %%
dataset["al"] = dataset["al"].fillna(0)

# %%
dataset["al"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["sg"].isna().sum()
# Out:
# np.int64(47)

# %%
dataset["sg"] = dataset["sg"].fillna(dataset["sg"].median())

# %%
dataset["sg"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["bp"].isna().sum()
# Out:
# np.int64(12)

# %%
dataset["bp"] = dataset["bp"].fillna(dataset["bp"].median())

# %%
dataset["bp"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["age"].isna().sum()
# Out:
# np.int64(9)

# %%
dataset["age"] = dataset["age"].fillna(dataset["age"].median())

# %%
dataset["age"].isna().sum()
# Out:
# np.int64(0)
